# %% [markdown]
# ## Pandas
#
# Pandas is python library built on top of NumPy.
#
# It provides high-perfomance data sctructures and tools for working with labeled data.
#
# Core Objects:
# Series => 1D labeled array
# DataFrame => 2D labeled table(like excel/sql)
#
# Pandas provides an efficient implementation of a DataFrame.
#
# DataFrames are essentially multidimensional arrays with attched row and column labels and often heterogeneous types and/or missing data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#A series is an array with labels(index)
s = pd.Series([10,20,30,40], index = ["a", "b", "c", "d"])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
#A dataframe is like an excel or sql table
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25,30,35],
    "City": ["Nairobi", "Kisumu", "Mombasa"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age     City
# 0    Alice   25  Nairobi
# 1      Bob   30   Kisumu
# 2  Charlie   35  Mombasa

# %% [markdown]
# # FEATURES
# # reading/writing data
#
# Pandas can be used for reading/writing data: csv, excel, json, sql
#
# df = pd.read_csv("data.csv")
# df.to_excel("data.xlsx")
#
# # data selection
# Pandas can also be used for data selection
#
# df["Name"]  => Column
#
# df.loc[0] => Row by label
#
# df.iloc[1] => Row by index
#
# # data filtering
#
# df[df["Age"] > 28]
#
# # data aggregation
#
# df["Age"].mean()
#
# df.groupby("City")["Age"].mean()
#
# # data merging/joining
#
# pd.merge(df1, df2, on="id")

# %%
#Example on data merging
df1 = pd.DataFrame({'id': [1, 2, 3], 'value1': [10,20,30]})
df2 = pd.DataFrame({'id': [1, 2, 3], 'value1': [100,200,300]})

df_merged = pd.merge(df1, df2, on= 'id')

print(df_merged)
# Out:
#    id  value1_x  value1_y
# 0   1        10       100
# 1   2        20       200
# 2   3        30       300

# %%
#data indexers
data = pd.Series(['a', 'b', 'c'], index = [1,3,5])
print(data)
print("---------------------")
#print(data[1])
print(data.loc[1])
print("---------------------")
print(data.iloc[1])
print("---------------------")
#slicing with loc and iloc
print(data.loc[1:3])
print("---------------------")
print(data.iloc[1:3])
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object
# ---------------------
# a
# ---------------------
# b
# ---------------------
# 1    a
# 3    b
# dtype: object
# ---------------------
# 3    b
# 5    c
# dtype: object

# %% [markdown]
# # Reading CSV Files using Pandas

# %%
fish_species = pd.read_csv("fish.csv")

# %% [markdown]
# #### Displaying a DataFrame

# %%
fish_species
# Out:
#     species  mass_g  length_cm
# 0     Bream   242.0       23.2
# 1     Bream   290.0       24.0
# 2     Bream   340.0       23.9
# 3     Bream   363.0       26.3
# 4     Bream   430.0       26.5
# ..      ...     ...        ...
# 123    Pike   950.0       48.3
# 124    Pike  1250.0       52.0
# 125    Pike  1600.0       56.0
# 126    Pike  1550.0       56.0
# 127    Pike  1650.0       59.0
#
# [128 rows x 3 columns]

# %% [markdown]
# ## Inspecting a DataFrame

# %%
fish_species.head(10) #dsiplays the first 5 rows
# Out:
#   species  mass_g  length_cm
# 0   Bream   242.0       23.2
# 1   Bream   290.0       24.0
# 2   Bream   340.0       23.9
# 3   Bream   363.0       26.3
# 4   Bream   430.0       26.5
# 5   Bream   450.0       26.8
# 6   Bream   500.0       26.8
# 7   Bream   390.0       27.6
# 8   Bream   450.0       27.6
# 9   Bream   500.0       28.5

# %%
fish_species.tail(10)
# Out:
#     species  mass_g  length_cm
# 118    Pike   510.0       40.0
# 119    Pike   540.0       40.1
# 120    Pike   500.0       42.0
# 121    Pike   567.0       43.2
# 122    Pike   770.0       44.8
# 123    Pike   950.0       48.3
# 124    Pike  1250.0       52.0
# 125    Pike  1600.0       56.0
# 126    Pike  1550.0       56.0
# 127    Pike  1650.0       59.0

# %%
# Using the .info() method to get a concise summary of the DataFrame

fish_species.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   species    128 non-null    object
#  1   mass_g     128 non-null    float64
#  2   length_cm  128 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# # Selecting Columns
#
# Why selext columns:
#
#  - Use the in calculation
#
#  - Plot data

# %%
# Finding the sum of the total mass of all species in the dataset

total_mass = fish_species.mass_g.sum()
print(total_mass)
# Out:
# 58288.4

# %%
#Plotting mass against length

plt.plot(fish_species["mass_g"], fish_species["length_cm"])

# %% [markdown]
# ## Column names are just Strings
#
# -So when combining string we need to use quotation marks

# %%
fish_species.head()
# Out:
#   species  mass_g  length_cm
# 0   Bream   242.0       23.2
# 1   Bream   290.0       24.0
# 2   Bream   340.0       23.9
# 3   Bream   363.0       26.3
# 4   Bream   430.0       26.5

# %% [markdown]
# ## Selecting column with Brackets and String

# %%
species = fish_species["species"]
print(species)
# Out:
# 0      Bream
# 1      Bream
# 2      Bream
# 3      Bream
# 4      Bream
#        ...
# 123     Pike
# 124     Pike
# 125     Pike
# 126     Pike
# 127     Pike
# Name: species, Length: 128, dtype: object

# %% [markdown]
# ## Selecting Column with a dot

# %%
mass_of_species = fish_species.mass_g

print(mass_of_species)
# Out:
# 0       242.0
# 1       290.0
# 2       340.0
# 3       363.0
# 4       430.0
#         ...
# 123     950.0
# 124    1250.0
# 125    1600.0
# 126    1550.0
# 127    1650.0
# Name: mass_g, Length: 128, dtype: float64

# %% [markdown]
# # Selecting Rows with Logic
#
# -This builds up on the concept of logical operators and logical statements
#
# -Logical Operators include:
#     -and
#     -or
#     -not
#     -greater than >
#     -less than <
#     -equal to ==
#     -not equal to <=

# %%
# Using logic with dataframes

fish_longer_than_40 = fish_species.length_cm > 40
print(fish_longer_than_40)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 123     True
# 124     True
# 125     True
# 126     True
# 127     True
# Name: length_cm, Length: 128, dtype: bool

# %%
fish_species[fish_species.length_cm != 40]
# Out:
#     species  mass_g  length_cm
# 0     Bream   242.0       23.2
# 1     Bream   290.0       24.0
# 2     Bream   340.0       23.9
# 3     Bream   363.0       26.3
# 4     Bream   430.0       26.5
# ..      ...     ...        ...
# 123    Pike   950.0       48.3
# 124    Pike  1250.0       52.0
# 125    Pike  1600.0       56.0
# 126    Pike  1550.0       56.0
# 127    Pike  1650.0       59.0
#
# [126 rows x 3 columns]

# %%
fish_species[fish_species.mass_g <= 20]
# Out:
#    species  mass_g  length_cm
# 40   Roach     0.0       19.0
# 55   Perch     5.9        7.5

# %% [markdown]
# # Another Example

# %%
female_data = pd.read_csv("ANSUR_II_FEMALE.csv")

male_data = pd.read_csv("ANSUR_II_MALE.csv")

combined_data = pd.concat([female_data, male_data], ignore_index=True)

# %%
female_data.head()
# Out:
#                    Branch     Component  Gender  \
# 0          Combat Support  Regular Army  Female
# 1  Combat Service Support  Regular Army  Female
# 2  Combat Service Support  Regular Army  Female
# 3  Combat Service Support  Regular Army  Female
# 4             Combat Arms  Regular Army  Female
#
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             231            1282                    301
# 1                             194            1379                    320
# 2                             183            1369                    329
# 3                             261            1356                    306
# 4                             309            1303                    308
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 204          1180                      222
# 1                 207          1292                      225
# ...

# %%
male_data.head()
# Out:
#                    Branch     Component Gender  \
# 0             Combat Arms  Regular Army   Male
# 1          Combat Support  Regular Army   Male
# 2          Combat Support  Regular Army   Male
# 3  Combat Service Support  Regular Army   Male
# 4  Combat Service Support  Regular Army   Male
#
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             266            1467                    337
# 1                             233            1395                    326
# 2                             287            1430                    341
# 3                             234            1347                    310
# 4                             250            1585                    372
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 222          1347                      253
# 1                 220          1293                      245
# ...

# %%
combined_data.head()
# Out:
#                    Branch     Component  Gender  \
# 0          Combat Support  Regular Army  Female
# 1  Combat Service Support  Regular Army  Female
# 2  Combat Service Support  Regular Army  Female
# 3  Combat Service Support  Regular Army  Female
# 4             Combat Arms  Regular Army  Female
#
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             231            1282                    301
# 1                             194            1379                    320
# 2                             183            1369                    329
# 3                             261            1356                    306
# 4                             309            1303                    308
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 204          1180                      222
# 1                 207          1292                      225
# ...

# %% [markdown]
# # Pandas string operations
# Pandas provides a set of vectorized string operations via the .str attribute on Series and Index objects. This is crucial since the string operations can hanldle missing data.

# %%
monte = pd.Series(['Graaham Chapman', 'John Cleese', 'Terry Gilliam' 'Eric Dundle', 'Terry Jones', 'Michael Palin'])
print(monte.str.capitalize())
print("-----------------")
print(monte.str.len())
print("-----------------")
monte.str.lower()
print("------------------------")
monte.str.startswith("T")
print("---------------------")
monte.str.split
# Out:
# 0             Graaham chapman
# 1                 John cleese
# 2    Terry gilliameric dundle
# 3                 Terry jones
# 4               Michael palin
# dtype: object
# -----------------
# 0    15
# 1    11
# 2    24
# 3    11
# 4    13
# dtype: int64
# -----------------
# ------------------------
# ---------------------
# <bound method StringMethods.split of <pandas.core.strings.accessor.StringMethods object at 0x00000266FFAF08D0>>

# %% [markdown]
# # USING REGEX to operate on strings

# %%
monte.str.extract('([A-Za-z]+)', expand=False)
# Out:
# 0    Graaham
# 1       John
# 2      Terry
# 3      Terry
# 4    Michael
# dtype: object

# %%
monte.str.findall(r'^[^AEIOU].*[aeiou]$')
# Out:
# 0                            []
# 1                 [John Cleese]
# 2    [Terry GilliamEric Dundle]
# 3                            []
# 4                            []
# dtype: object

# %%
monte.str.replace('Terry', 'Terrence')
# Out:
# 0                Graaham Chapman
# 1                    John Cleese
# 2    Terrence GilliamEric Dundle
# 3                 Terrence Jones
# 4                  Michael Palin
# dtype: object

# %%
monte.str.count('J')
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# dtype: int64
